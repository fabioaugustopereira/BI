# %% [markdown]
# <a href="https://colab.research.google.com/github/fabioaugustopereira/BI/blob/main/lista0/figuras_3D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando biblioteca
import matplotlib.pyplot as plt

# facilita visualizacao de figuras 3D
from mpl_toolkits.mplot3d import axes3d # graficos 3D sao habilitados importando axes3d

# para figuras interativas usar “notebook” ao inves de “inline” %matplotlib notebook
ax = plt.subplot(111, projection='3d')
X, Y, Z = axes3d.get_test_data(0.1)
ax.plot_wireframe(X, Y, Z)

# salva figura em arquivo
plt.savefig('figura3d.png')
